# %%
# execute as if in root folder for utils and filepaths
# %cd ..
# Out:
# c:\Users\sonja\OneDrive\Uni\Semester 6\BachelorArbeit\practical-work-ai-bsc
# C:\Users\sonja\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader,TensorDataset
import numpy as np
import random
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import json
from torch.utils.tensorboard import SummaryWriter
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, auc, precision_recall_curve , average_precision_score
from torch.optim.lr_scheduler import ReduceLROnPlateau


from utils import get_support_query_loaders, log_results_nn_ft, NeuralNetwork, save_best_model, classification_loss, propagation_loss, getPrAucIndividualClassFinetuning

# %%
data = np.load('./data/data_scaled.npz')
X_finetuning = data['X_finetuning']
y_ft1 = data['y_finetuning1']
y_ft2 = data['y_finetuning2']

# %%
seeds = [2608, 2831, 3525, 3127, 9549, 9299, 896, 8017, 106, 7039]

# %%
def label_propagation(X, Y, alpha):
    """
    X: input features
    Y: one hot vector of n x c dimensions; c is num of different labels
    alpha: hyperparameter that controls how much influence neighbors get, [0,1]: 0: predict only 0s, 1: predict only 1s
    """
    device = X.device
    # affinity matrix W
    sq = torch.sum(X ** 2, dim=1, keepdim=True)  # shape: (num_samples, 1)
    distances_squared = sq + sq.t() - 2 * (X @ X.t())
    sigma2 = torch.var(distances_squared)
    W = torch.exp(-distances_squared / (2*sigma2) )
    W.fill_diagonal_(0)

    # diagonal matrix
    row_sums = torch.sum(W, dim=1)
    D12 = torch.diag(1 / torch.sqrt(row_sums))
    
    S = D12 @ W @ D12

    # F*
    I = torch.eye(X.shape[0], device=device, dtype=X.dtype)
    temp = (I - alpha * S).float()
    F_star = torch.linalg.solve(temp, Y) # solve MF = Y for F, avoid direct inverse

    # label each point x_i as y_i = argamx F*_ij
    L = torch.argmax(F_star, dim=1)

    return L

# %%
def prepare_labels_label_propagation(len_X_support, len_X_query, y_support, device, num_classes=2):
    y_support = y_support.clone().detach().long()
    zeros = torch.zeros((len_X_query, num_classes), dtype=torch.float, device=device)
    one_hot_y= nn.functional.one_hot(y_support, num_classes,).float().to(device)
    Y = torch.concatenate((one_hot_y, zeros))
    return Y

# %%
def scatterplot_propagated_labels(X, y1, y2):
    pca = PCA(n_components=2, random_state=0)
    X2 = pca.fit_transform(X)

    # Prepare subplots
    fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharex=True, sharey=True)

    for ax, (y, title) in zip(axes, [(y1, 'Labels → y1'), (y2, 'Labels → y2 (None→grey)')]):
        # Find unique real classes (ignore None/nan)
        classes = [c for c in np.unique(y) if c is not None and not (isinstance(c, float) and np.isnan(c))]
        # Plot each real class with default cycle
        for cls in classes:
            mask = (y == cls)
            ax.scatter(
                X2[mask, 0], X2[mask, 1],
                label=f'Class {cls}',
                s=20, alpha=0.5, edgecolors='face'
            )
        # Plot missing (None/nan) as grey
        missing_mask = [(v is None) or (isinstance(v, float) and np.isnan(v)) for v in y]
        if any(missing_mask):
            ax.scatter(
                X2[missing_mask, 0], X2[missing_mask, 1],
                label='Missing',
                color='lightgrey',
                s=20, alpha=0.1, edgecolors='face'
            )
        ax.set_title(title, fontsize=16)
        ax.set_xlabel('PC1', fontsize=14)
        ax.set_ylabel('PC2', fontsize=14)
        ax.legend(title='Label', fontsize=12, title_fontsize=12, loc='best')
        ax.grid(True)

    plt.tight_layout()
    plt.show()

# %%
# task_idx = 2
# support_loader, _, support_idx, query_idx = get_support_query_loaders(X_finetuning, y_ft1, task_idx, k=1, l=30, max_pos_query=10, seed=12576, batch_size=120, num_workers=0)
# print(y_ft1[support_idx, task_idx])
# Y = prepare_labels_label_propagation(len(support_idx), len(query_idx), y_ft1[support_idx, 2])
# episode_idx = np.concatenate((support_idx, query_idx))
# propagated_labels = label_propagation(torch.tensor(X_finetuning[episode_idx], device="cuda"), torch.tensor(Y, device="cuda"), alpha=0.0000000000000001)

# %%
# scatterplot_propagated_labels(X_finetuning[episode_idx], propagated_labels.cpu(), y_ft1[episode_idx, task_idx])

# %%
def train_few_shot_model(model, X, y, task_idx, optimizer, scheduler, device, writer, run, k, l, max_pos_query, seed, alpha, max_episodes=10, patience=100, batch_size=120, num_workers=0):
    """
    model          : your NeuralNetwork instance
    X, y           : numpy arrays (N, D) and (N, T)
    criterion      : loss fn, e.g. BCEWithLogitsLoss()
    optimizer      : your torch optimizer
    device         : torch.device
    writer         : tensorboard writer
    run            : an identifier for the saved filename
    k, seed        : few-shot support size and RNG seed
    """
    model.to(device)
    best_score = 0.0
    file_path = f"./best_models/ft1_vanilla_{run}.pth"

    X = torch.from_numpy(X).float().to(device)
    y = torch.from_numpy(y).float().to(device)

    epochs_no_improve = 0
    best_pr_auc = None
    best_roc_auc = None
    pr_auc_per_task = None
    roc_auc_per_task = None
    last_improvement_episode = 0

    # generate support and query sets
    support_loader, query_loader, support_idx, query_idx = get_support_query_loaders(X, y, task_idx, k, l, max_pos_query, seed, batch_size=batch_size, num_workers=num_workers)

    for episode in range(1, max_episodes + 1):
        model.train()
        
        # ——— SUPPORT SET ———
        for inputs, labels in support_loader:
            # flatten if needed
            support_inputs = inputs.view(inputs.size(0), -1).to(device)
            support_labels = labels.to(device)

            optimizer.zero_grad()
            outputs_support = model(support_inputs)
            outputs_support = outputs_support.squeeze(1)

            loss_support = classification_loss(outputs_support, support_labels)


        # ——— LOSS AND UPDATE STEP ——— # 
        optimizer.zero_grad()
        loss_support.backward()
        optimizer.step()
        scheduler.step(loss_support)

        ################# EVAL #################
        # ——— QUERY SET ——— #
        model.eval()
        all_labels_val = []
        all_preds_val = []

        for inputs, labels in query_loader:
            query_inputs = inputs.to(device)
            query_labels = labels.to(device)

            outputs_query = model(query_inputs)
            outputs_query = outputs_query.squeeze(1)

            loss_query = classification_loss(outputs_query, query_labels) # only for logging

            all_labels_val.append(labels.cpu().numpy())
            all_preds_val.append(torch.sigmoid(outputs_query).detach().cpu().numpy())

        # ——— LABEL PROPAGATION ——— # 
        episode_idx = np.concatenate((support_idx, query_idx))
        Y = prepare_labels_label_propagation(len(support_idx), len(query_idx), y[support_idx, task_idx], device)
        propagated_labels = label_propagation(X[episode_idx], Y, alpha=alpha)
        query_logits = propagated_labels[len(support_idx):]
        loss_label_prop = propagation_loss(query_logits.float(), query_labels.float())


        # ——— EVALUATE MODEL ——— # 
        final_preds = (all_preds_val[0] + np.array(query_logits.cpu())) / 2 # final predictions are avg of model preds and label prop preds
        val_loss = classification_loss(torch.tensor(final_preds), torch.tensor(all_labels_val[0]))
        #test = [final_preds.reshape(-1)]
        val_pr_auc, val_roc_auc, val_pr_auc_per_task, val_roc_auc_per_task = getPrAucIndividualClassFinetuning(
            "Val", all_labels_val, [final_preds.reshape(-1)], writer, episode
        )

        # run.log({
        #         "episode": episode,
        #         "train_loss": loss_support,
        #         "query_loss": loss_query,
        #         "lp_loss": loss_label_prop,
        #         "val_loss": val_loss,
        #         "pr_auc": val_pr_auc,
        #         "roc_auc": val_roc_auc
        #     })

        # ——— SAVE BEST MODEL ——— # 
        saved = save_best_model(model, avg_pr_auc=val_pr_auc,best_score=best_score, file_path=file_path)
        if saved:
            best_score = val_pr_auc
            epochs_no_improve = 0
            last_improvement_episode = episode
            # save results
            best_pr_auc = np.mean(val_pr_auc)
            best_roc_auc = np.mean(val_roc_auc)
            pr_auc_per_task = np.mean(val_pr_auc_per_task, axis=0)
            roc_auc_per_task = np.mean(val_roc_auc_per_task, axis=0)
        else:
            epochs_no_improve += 1

        # early stopping
        if epochs_no_improve >= patience:
            print(f"Stopping early at episode {episode} (no improvement in {patience} episodes)")
            break

        


    print(
        f"=== Best Model Evaluation ===\n"
        f"Avg PR-AUC: {best_pr_auc:.4f}, Avg ROC-AUC: {best_roc_auc:.4f}"
    )

    return best_pr_auc, best_roc_auc, pr_auc_per_task, roc_auc_per_task, last_improvement_episode

# %%
# hyperparameters & global vars
input_size = 2248 
hidden_sizes = [120, 48, None]
output_size = 9
batch_size = 500
lr = 0.2941271118953339
k = 1
l = 10
max_episodes = 1205
patience = 282
max_pos_query= int(l/2)
alpha =0.2538481528053722
dropout_rates = [0.3, 0.5] # input dropout, hidden dropout
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# list to collect results avg over task
avg_results = {
        "Delta-AUC-PR": [],
        "ROC-AUC": []
    }

# list to collect results per task
all_results = {
        "Delta-AUC-PR": [],
        "ROC-AUC": []
    }  

num_tasks = 4
num_runs  = 5
last_improvement_episodes = np.zeros((num_tasks, num_runs))

for task_idx in range(4):
    # train and evaluate model 5 times
    for run in range(5):
        # set seed
        seed_value = seeds[run]
        torch.manual_seed(seed_value)
        if torch.cuda.is_available():
            torch.cuda.manual_seed(seed_value)
            torch.cuda.manual_seed_all(seed_value)
        np.random.seed(seed_value)
        random.seed(seed_value)

        # initialize
        # writer = SummaryWriter(f"manual_runs/run_36_upsampling") # tensorboard
        writer = None
        model = NeuralNetwork(input_size, hidden_sizes, output_size, dropout_rates)

        # load best model
        state_dict = torch.load("./best_models/overall_best_vanilla.pth", map_location=device)
        model.load_state_dict(state_dict)

        # freeze all parameters except the last layer (fc3)
        for name, param in model.named_parameters():
            if not name.startswith("fc3"):
                param.requires_grad = False

        # check if all frozen:
        for name, param in model.named_parameters():
            print(name, param.requires_grad)
            
        # replace fc3 with a new Linear that has a single output neuron
        in_features = model.fc3.in_features # keep input features as they are
        model.fc3 = nn.Linear(in_features, 1) # replace output features
        optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=lr) # filter out all parameters except last layer
        scheduler = ReduceLROnPlateau(optimizer,
                                mode='min',
                                factor=0.1,
                                patience=20,
                                min_lr=1e-6)

        # train model
        val_delta_auc_pr, val_roc_auc, _, _, last_improvement_episode = train_few_shot_model(model, X_finetuning, y_ft1, task_idx, optimizer, scheduler, device, writer, run, k, l, max_pos_query, seed_value, alpha, max_episodes, patience, batch_size=batch_size, num_workers=0)
        
        # collect results per run
        all_results["Delta-AUC-PR"].append(val_delta_auc_pr)
        all_results["ROC-AUC"].append(val_roc_auc) 
        # writer.close()

        last_improvement_episodes[task_idx, run] = last_improvement_episode
# Out:
# cuda
# fc1.weight False
# fc1.bias False
# fc2.weight False
# fc2.bias False
# fc3.weight True
# fc3.bias True
# torch.Size([10]) torch.Size([10])
# Saved new best model with avg PR AUC: 0.1357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0667 did not improve over best score: 0.1357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0857 did not improve over best score: 0.1357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0560 did not improve over best score: 0.1357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0949 did not improve over best score: 0.1357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.1357
# torch.Size([10]) torch.Size([10])
# Saved new best model with avg PR AUC: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2500 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2500 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2500 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2778 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0413 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0884 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1051 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0995 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0862 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0933 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0933 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0790 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1124 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0924 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0924 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0924 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0924 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0924 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0924 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0924 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0924 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0924 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0995 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0995 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1051 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0551 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0551 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0884 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0827 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1484 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1484 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1484 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1270 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1270 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2056 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2056 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1484 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1484 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1484 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0684 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0827 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0827 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0827 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0827 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0827 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0827 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1027 did not improve over best score: 0.2778
# Stopping early at episode 289 (no improvement in 282 episodes)
# === Best Model Evaluation ===
# Avg PR-AUC: 0.2778, Avg ROC-AUC: 0.6000
# fc1.weight False
# fc1.bias False
# fc2.weight False
# fc2.bias False
# fc3.weight True
# fc3.bias True
# torch.Size([10]) torch.Size([10])
# Saved new best model with avg PR AUC: 0.1143
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1143 did not improve over best score: 0.1143
# torch.Size([10]) torch.Size([10])
# Saved new best model with avg PR AUC: 0.1643
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0665 did not improve over best score: 0.1643
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1159 did not improve over best score: 0.1643
# torch.Size([10]) torch.Size([10])
# Saved new best model with avg PR AUC: 0.1730
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1050 did not improve over best score: 0.1730
# torch.Size([10]) torch.Size([10])
# Saved new best model with avg PR AUC: 0.2357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1270 did not improve over best score: 0.2357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1592 did not improve over best score: 0.2357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0411 did not improve over best score: 0.2357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0071 did not improve over best score: 0.2357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1643 did not improve over best score: 0.2357
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1643 did not improve over best score: 0.2357
# torch.Size([10]) torch.Size([10])
# Saved new best model with avg PR AUC: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2138 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1327 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1353 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0746 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0879 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0756 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1790 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0635 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1148 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0199 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1675 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0678 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0806 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1216 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1169 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1169 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0356 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1073 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0022 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0073 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1228 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0700 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0311 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0311 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0464 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1311 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0675 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0689 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1840 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1409 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0230 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0087 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0294 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0478 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1767 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0167 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2413 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2413 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1317 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2233 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0700 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1081 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0689 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0641 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0230 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1950 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1964 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.2018 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1841 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1730 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1950 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1770 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2230 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1659 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.2659 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1214 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1008 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0286 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1270 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1950 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0730 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1204 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1270 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1315 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1032 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1398 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1509 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1398 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0128 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1546 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0635 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0617 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0778 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0105 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0389 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1890 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1169 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1840 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1294 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1354 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1294 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0506 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0117 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0189 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0086 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1675 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1792 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0578 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0969 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0189 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1424 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0522 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1327 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1840 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0689 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0606 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0606 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0522 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0606 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1424 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1169 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1675 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1287 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1241 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0606 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0294 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0506 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0294 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1354 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1327 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0878 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0189 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1287 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1478 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1354 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1354 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0117 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1241 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1424 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0606 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0117 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1436 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0086 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0578 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0932 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1294 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1424 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1241 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1354 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1241 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1241 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1478 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1241 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1073 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0932 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0578 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.0128 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0806 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1354 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0617 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1471 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0522 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0932 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1840 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0969 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1287 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0969 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1241 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0806 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1294 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1241 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0506 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1241 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0969 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0578 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0189 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1792 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0806 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1327 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0522 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1792 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1398 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0117 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0617 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0932 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: 0.1058 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0506 did not improve over best score: 0.3048
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.1169 did not improve over best score: 0.3048
# ...
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# torch.Size([10]) torch.Size([10])
# Current avg PR AUC: -0.0865 did not improve over best score: 0.5083
# Stopping early at episode 287 (no improvement in 282 episodes)
# === Best Model Evaluation ===
# Avg PR-AUC: 0.5083, Avg ROC-AUC: 0.8750

# %%
filepath_normal = "./metrics/vanilla_ft1.json"
filepath_per_task = "./metrics/vanilla_ft1_per_task.json"
filepath_per_run = "./metrics/vanilla_ft1_per_run.json"
log_results_nn_ft(all_results, filepath_normal, filepath_per_run, filepath_per_task)

# %%
# get avg stopping episode
last_improvement_episodes
# Out:
# array([[  7., 261.,   8.,   1.,   9.],
#        [  2.,  19.,   3.,  60.,  59.],
#        [ 31.,   6.,   8.,  20.,   6.],
#        [  3.,  21.,   5.,  41.,   5.]])

# %%
np.median(last_improvement_episodes)
# Out:
# 8.0
